# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenb-16/ML-ex-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

# Create finds.csv file automatically
with open("finds.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Sunny", "Warm", "Normal", "Strong", "Warm", "Same", "Yes"])
    writer.writerow(["Sunny", "Warm", "High", "Strong", "Warm", "Same", "Yes"])
    writer.writerow(["Rainy", "Cold", "High", "Strong", "Warm", "Change", "No"])
    writer.writerow(["Sunny", "Warm", "High", "Strong", "Cool", "Change", "Yes"])


def read_data(filename):
    with open(filename, 'r') as csvfile:
        datareader = csv.reader(csvfile)
        traindata = []
        for row in datareader:
            if row:
                traindata.append(row)
    return traindata


h = ['phi', 'phi', 'phi', 'phi', 'phi', 'phi']

data = read_data('finds.csv')


def isConsistent(h, d):
    if len(h) != len(d) - 1:
        print('Number of attributes are not same in hypothesis.')
        return False
    else:
        matched = 0
        for i in range(len(h)):
            if (h[i] == d[i]) or (h[i] == 'any'):
                matched += 1
        return matched == len(h)


def makeConsistent(h, d):
    for i in range(len(h)):
        if h[i] == 'phi':
            h[i] = d[i]
        elif h[i] != d[i]:
            h[i] = 'any'
    return h


print('Begin : Hypothesis :', h)

for d in data:
    if d[-1].strip().lower() == 'yes':
        if not isConsistent(h, d):
            h = makeConsistent(h, d)
        print("Updated Hypothesis :", h)

print("Final Hypothesis :", h)
# Out:
# Begin : Hypothesis : ['phi', 'phi', 'phi', 'phi', 'phi', 'phi']
# Updated Hypothesis : ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
# Updated Hypothesis : ['Sunny', 'Warm', 'any', 'Strong', 'Warm', 'Same']
# Updated Hypothesis : ['Sunny', 'Warm', 'any', 'Strong', 'any', 'any']
# Final Hypothesis : ['Sunny', 'Warm', 'any', 'Strong', 'any', 'any']
